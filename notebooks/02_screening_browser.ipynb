# %% [markdown]
# # Screening browser
#
# ## Imports

# %%
from pathlib import Path
import photon_tools as pt

# %% [markdown]
# ## Set path to data directory

# %%
# set data directory
DATA = Path("../tests/data")

# create file path list of all files with file format suffix .h5
paths = sorted(DATA.glob("*.h5"))

# %% [markdown]
# ## Create file browser

# %%
# the browser is opened twice without ui=
ui = pt.browse_files(paths=paths, results_path="screening_results.csv")
