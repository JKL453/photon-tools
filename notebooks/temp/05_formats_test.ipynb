# %%
import photon_tools as pt

# %%
# SPC
spc_path = "/Users/kappel/Downloads/001_7bp_4str_DNA_AF488_AF647_40uW488nm_10uW640nm_30min_bebCS_BenchmBuffer_ctrl.spc"
spc_path = "/Users/kappel/Downloads/test.spc"
ds = pt.load(spc_path)  # timing_resolution kommt aus file
fig = pt.preview(ds, bin_width_ms=10, detector_labels={0:"APD1", 1:"APD2"})

# %%
# NI binary
ni_binary_path = "/Users/kappel/Downloads/001_9bp_AT488_AT647N_488_5uW_638p_2_5uW_1800"
ni_binary_path = "/Users/kappel/Downloads/H2O_40uW_120s"
ds2 = pt.load(ni_binary_path, loader=pt.load_ni_binary, timing_resolution=10e-9)
fig = pt.preview(ds2, bin_width_ms=10, detector_labels={0:"APD1", 1:"APD2"})
